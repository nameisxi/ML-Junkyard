# %% [markdown]
# # Chapter 3 Exercises on R

# %%
install.packages('ISLR')
# Out:
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5:
#   cannot open URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5/PACKAGES'"
# package 'ISLR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Tuomas\AppData\Local\Temp\RtmpCCkAyO\downloaded_packages

# %%
library(MASS)
library(ISLR)

# %%
fix(Boston)
names(Boston)
# Out:
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
pairs(Boston)
# Out:
# plot without title

# %%
attach(Boston)
plot(lstat, medv)
# Out:
# plot without title

# %%
# medv = median value of owner-occupied homes in $1000s.
# lstat = lower status of the population (percent).

# %%
lm.fit = lm(medv~lstat)

# %%
summary(lm.fit)
# Out:
# Call:
# lm(formula = medv ~ lstat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.168  -3.990  -1.318   2.034  24.500
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.55384    0.56263   61.41   <2e-16 ***
# lstat       -0.95005    0.03873  -24.53   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6.216 on 504 degrees of freedom
# Multiple R-squared:  0.5441,	Adjusted R-squared:  0.5432
# F-statistic: 601.6 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
plot(lstat, medv)
abline(lm.fit, lwd=3, col="red")
# Out:
# plot without title

# %%
par(mfrow=c(2,2))
plot(lm.fit)
# Out:
# Plot with title ""

# %%
plot(predict(lm.fit), residuals(lm.fit))
# Out:
# plot without title

# %%
plot(hatvalues(lm.fit))
# Out:
# plot without title

# %%
which.max(hatvalues(lm.fit))
# Out:
# 375
# 375

# %%
lm.fit = lm(medv~lstat+age)

# %%
summary(lm.fit)
# Out:
# Call:
# lm(formula = medv ~ lstat + age)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.981  -3.978  -1.283   1.968  23.158
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 33.22276    0.73085  45.458  < 2e-16 ***
# lstat       -1.03207    0.04819 -21.416  < 2e-16 ***
# age          0.03454    0.01223   2.826  0.00491 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 6.173 on 503 degrees of freedom
# Multiple R-squared:  0.5513,	Adjusted R-squared:  0.5495
# F-statistic:   309 on 2 and 503 DF,  p-value: < 2.2e-16

# %%
lm.fit = lm(medv~., data=Boston)

# %%
par(mfrow=c(2,2))
plot(lm.fit)
# Out:
# Plot with title ""

# %% [markdown]
# 2. Like with most other classifiers and regressors, the main difference is that of their output. Classifiers output either a class, or a probability. In the case of KNN classifier, its output is a class (qualitative). Regressors instead return quantitative prediction, like a price and this holds true on KNN regressor.
#
#
# 3. a) III. is the correct answer for the following reasons:
#       First, in all cases GPA has a really high coefficient (20), where as IQ doesn't (0.07).
#       Also the interaction predictor between IQ and GPA seems to have little difference with coefficient of 0.01.
#       So provided that GPA is high, IQ doesn't seem to be the predictor that makes all the difference. This
#       leaves us with two more asnwers: III and IV. The reason why males will earn more with the provided model
#       is that of the lower coefficient in X5 * B5 = -10(GPA * Gender). When the gender predictor itself is 0 (Male),
#       the answer is always going to be 0, where as with predictor value 1 (Female), it's going to be -40, provided
#       that the GPA is high (4.0).
#
#       Males with high GPAs = 50 + 20(4) + 0.07(100) + 0.01(400) = 141
#
#       Females with high GPAs = 50 + 20(4) + 0.07(100) + 35 + 0.01(400) - 10(4 * 1) = 136
#
#    b) 137.1
#
#    c) I'd say False since it can at best bring a difference of about ~$6K and we don't have a p value to tell it's
#       statistical  importance.
#
#
# 4. a) I'd expect the train RSS be better, since it would highly overfit.
#
#    b) With test, RSS would be much higher because of the overfitting.
#
#    c) RSS using train data would definitely be better with a polynomial model.
#
#    d) RSS using test data with polynomial model could actually be better since the data could be extremely far from linear.
#
#
# 6.
